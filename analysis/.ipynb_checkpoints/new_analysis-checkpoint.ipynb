# %% [markdown]
# # Introduction

# %% [markdown]
# This is the ipython notebook file where our group did the most of our data analysis. Feel free to run the individual cells and follow along with the comments. It's not very hard to understand and quite straightfoward.
#
# PS. Hello Professor Zhang! 🙋‍♂️

# %%
# Data Analysis Packages
from sklearn import preprocessing
import pandas as pd
import numpy as np
import pickle as pk

# %%
# Graphing Packages
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# # Import and Save Data

# %% [markdown]
# ### Bitcoin Block Data (from Prof. Zhang)

# %%
# Import BTC Dataset given to us by Prof. Zhang
file_location = 'og_data_csv\\og_block_data.csv'
btc_block_data = pd.read_csv(file_location,low_memory=False)

# Save the data as a pickled pandas dataframe
pk.dump(btc_block_data, open( "og_data_binary\\og_block_data.p", "wb" ) )

# %% [markdown]
# ### Crypto Search Data (from Google Trends)

# %%
# Import pytrends package
from pytrends.request import TrendReq

# Set the keyword & timeframe
keywords = ["Bitcoin", "Ethereum"]
pt.build_payload(keywords, timeframe="all")

# Get the interest over time
crypto_search = pt.interest_over_time()

# Save search data as pickled pandas datafame and .csv file
pk.dump(crypto_search, open( "og_data_binary\\og_search_data.p", "wb" ) )
crypto_search.to_csv("og_data_csv\\og_search_data.csv")

# %% [markdown]
# ### Crypto Price Data (from Yahoo Finance)

# %%
# Import yfinance package
import yfinance as yf
crypto_price = yf.download("BTC-USD", start="2009-01-01", end="2021-01-19",interval = "1d")

# Save price data as pickled pandas datafame and .csv file
pk.dump(crypto_price, open( "og_data_binary\\og_price_data.p", "wb" ) )
crypto_price.to_csv("og_data_csv\\og_price_data.csv")

# %% [markdown]
# ### Check that everything was imported and saved successfully

# %%
# Bitcoin block data
pk.load(open("og_data_binary\\og_block_data.p", "rb"))
# Out:
#         height        host  volume  stripped_size     size   weight  \
# 0            0     unknown       1            285      285     1140
# 1            1     unknown       1            215      215      860
# 2            2     unknown       1            215      215      860
# 3            3     unknown       1            215      215      860
# 4            4     unknown       1            215      215      860
# ...        ...         ...     ...            ...      ...      ...
# 666611  666594      ViaBTC    1968         881571  1348518  3993231
# 666612  666595     Foundry    2474         893448  1312647  3992991
# 666613  666596      F2Pool    1896         819022  1541514  3998580
# 666614  666597  Huobi.pool    2192         912273  1256245  3993064
# 666615  666598     BTC.com    2331         886781  1333038  3993381
#
#         avg_trans_fee_per_trans  block_reward  block_reward_tips  \
# 0                      0.000000         50.00           0.000000
# 1                      0.000000         50.00           0.000000
# 2                      0.000000         50.00           0.000000
# 3                      0.000000         50.00           0.000000
# 4                      0.000000         50.00           0.000000
# ...                         ...           ...                ...
# 666611                 0.000239          6.25           0.953732
# 666612                 0.000160          6.25           0.637013
# 666613                 0.000123          6.25           0.493446
# 666614                 0.000040          6.25           0.158978
# 666615                 0.000117          6.25           0.466599
#
#                    time
# 0        3/1/2009 18:15
# 1         9/1/2009 2:54
# 2         9/1/2009 2:55
# 3         9/1/2009 3:02
# 4         9/1/2009 3:16
# ...                 ...
# 666611  18/1/2021 10:29
# 666612  18/1/2021 10:33
# 666613  18/1/2021 10:41
# 666614  18/1/2021 10:40
# 666615  18/1/2021 10:48
#
# [666616 rows x 10 columns]

# %%
# Crypto search data
pk.load(open("og_data_binary\\og_search_data.p", "rb"))

# %%
# BTC-USD price data
pk.load(open("og_data_binary\\og_price_data.p", "rb"))

# %% [markdown]
# # Block & Search Data

# %% [markdown]
# ### Import the original datasets

# %%
# Bitcoin block data
og_block_data = pk.load(open("og_data_binary\\og_block_data.p", "rb"))
# Crypto search data
og_search_data = pk.load(open("og_data_binary\\og_search_data.p", "rb"))

# %%
# Truncate the data to match the date range of the bitcoin block dataset
new_search_data = og_search_data.truncate(
    before=list(og_search_data.index)[60],
    after=list(og_search_data.index)[204]
)
new_search_data

# %%
og_block_data = og_block_data.drop(['host','height'],inplace=False,axis=1)
print(list(og_block_data.columns))
dic = {}
for i in list(og_block_data.index)[:]:
    lst = [ ]
    for k in [og_block_data[c][i] for c in og_block_data.columns]:
        if type(k) == str:
            key = k.split(" ")[0]
            var = key.split('/')  
            try:
                new_key = var[-2] + '/' + var[-1]
            except:
                pass
        else:
            lst.append(k)
            
    if key not in dic.keys():
        dic[new_key] = lst
        
new_block_data = pd.DataFrame.from_dict(data=dic,orient='index',columns=list(og_block_data.columns)[:-1])
new_block_data
# Out:
# -------------------------------------------------------------------------
# KeyError                                Traceback (most recent call last)
# Input In [71], in <cell line: 1>()
# ----> 1 og_block_data.drop(['host','height'],inplace=True,axis=1)
#       2 print(list(og_block_data.columns))
#       3 dic = {}
#
# File ~\miniconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['host', 'height'] not found in axis"

# %%
# Create subplots
fig, ax = plt.subplots()
line1, = ax.plot(crypto_iot['Bitcoin'].truncate(before=list(crypto_iot.index)[55]), label="BTC")
line2, = ax.plot(crypto_iot['Ethereum'].truncate(before=list(crypto_iot.index)[55]), label="ETH")

# Create a legend for the plot
first_legend = ax.legend(handles=[line1,line2], loc='upper left')

# Add the legend manually to the Axes.
ax.add_artist(first_legend)

# Label the x and y axis
plt.xlabel("Date")
plt.ylabel("Relative Interest")

# Add a title to the plot
plt.title("Crypto Interest Over Time")

# Save the plot to present directory
plt.rcParams["figure.figsize"] = (20,12)
plt.savefig("plots\\crypto_iot.jpg", dpi = 300)
# Show the plot
plt.show()

# %% [markdown]
# 5. Import Google Trends data for regional search trends of "Bitcoin". Then save the Pandas DataFrame as ibr.csv file in the "data" folder

# %%
# the keyword to extract data
keyword = ["Bitcoin"]
pt.build_payload(keyword, timeframe="all")
# get the interest by country
ibr = pt.interest_by_region("COUNTRY", inc_low_vol=True, inc_geo_code=True)
# Convert the series ibr to pandas dataframe
ibr = pd.DataFrame(ibr)
# Sort the dataframe by the value of the column "Bitcoin"
ibr.sort_values("Bitcoin", inplace=True, ascending=False)
# Save the dataframe to a csv file
ibr.to_csv("data\\ibr.csv")
ibr
# Out:
#                                   geoCode  Bitcoin
# geoName
# Nigeria                                NG      100
# El Salvador                            SV       71
# Namibia                                NA       63
# Eswatini                               SZ       58
# Cayman Islands                         KY       57
# ...                                   ...      ...
# Eritrea                                ER        0
# Pitcairn Islands                       PN        0
# Falkland Islands (Islas Malvinas)      FK        0
# Svalbard & Jan Mayen                   SJ        0
# Kiribati                               KI        0
#
# [250 rows x 2 columns]

# %% [markdown]
# ### Importing and Reading Bitcoin Price Data
#
# 1. Import Google Trends data for Coinbase and Binance, two of the largest cryptocurrency exchange. Then save the Pandas DataFrame as exch.csv file in the "data" folder

# %%
# import pandas_datareader as web
# import datetime as dt

# start = dt.datetime(2009,1,3)
# end = dt.datetime(2022,5,1)
# # end = dt.datetime.now()

# btc = web.DataReader('BTC-USD', 'yahoo', start, end)
# btc.to_csv("data\\exch.csv")

# for i in btc.index:
#     # print(str(i)[8:10])
#     if str(i)[8:10] != '01':
#         btc.drop(i, inplace=True)
# btc

# %%
iot_small = iot_small.set_index(new_df.index)
block_and_trends = pd.concat([new_df,iot_small],axis=1)
block_and_trends.to_csv("data\\block_and_trends.csv")
block_and_trends.drop('date',axis=1,inplace=True)
block_and_trends
# Out:
#          height  volume  stripped_size     size   weight  \
# 1/2009     2543       1            216      216      864
# 2/2009     5923       1            216      216      864
# 3/2009     9389       1            216      216      864
# 4/2009    12831       1            216      216      864
# 5/2009    16214       1            216      216      864
# ...         ...     ...            ...      ...      ...
# 9/2020   650731    2783         940687  1176404  3998465
# 10/2020  654932    2364         921982  1232764  3998710
# 11/2020  659398    2923         923692  1221624  3992700
# 12/2020  663912    2126         907164  1272042  3993534
# 1/2021   666598    2331         886781  1333038  3993381
#
#          avg_trans_fee_per_trans  block_reward  block_reward_tips  Bitcoin  \
# 1/2009                  0.000000         50.00           0.000000        0
# 2/2009                  0.000000         50.00           0.000000        0
# 3/2009                  0.000000         50.00           0.000000        0
# 4/2009                  0.000000         50.00           0.000000        0
# 5/2009                  0.000000         50.00           0.000000        0
# ...                          ...           ...                ...      ...
# 9/2020                  0.000122          6.25           0.485954       13
# 10/2020                 0.000168          6.25           0.670329       13
# 11/2020                 0.000221          6.25           0.880890       23
# 12/2020                 0.000088          6.25           0.349810       31
# 1/2021                  0.000117          6.25           0.466599       64
#
#          Ethereum  isPartial
# 1/2009          0      False
# 2/2009          0      False
# 3/2009          0      False
# 4/2009          0      False
# 5/2009          0      False
# ...           ...        ...
# 9/2020          2      False
# 10/2020         1      False
# 11/2020         3      False
# 12/2020         3      False
# 1/2021         11      False
#
# [145 rows x 11 columns]

# %%
#Scale the data
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0, 100))
scaled = min_max_scaler.fit_transform(block_and_trends)
block_and_trends_scaled = pd.DataFrame(scaled, columns = block_and_trends.columns)
block_and_trends_scaled = block_and_trends_scaled.set_index(block_and_trends.index)
block_and_trends_scaled
# pad_scaled.to_csv("data\\scale.csv")
# Out:
#              height     volume  stripped_size       size     weight  \
# 1/2009     0.000000   0.000000       0.000800   0.000579   0.000800
# 2/2009     0.508994   0.000000       0.000800   0.000579   0.000800
# 3/2009     1.030939   0.000000       0.000800   0.000579   0.000800
# 4/2009     1.549269   0.000000       0.000800   0.000579   0.000800
# 5/2009     2.058715   0.000000       0.000800   0.000579   0.000800
# ...             ...        ...            ...        ...        ...
# 9/2020    97.610589  77.342230      94.070101  85.115640  99.964417
# 10/2020   98.243218  65.693634      92.199159  89.194141  99.970543
# 11/2020   98.915752  81.234362      92.370199  88.387993  99.820258
# 12/2020   99.595515  59.077009      90.717009  92.036501  99.841113
# 1/2021   100.000000  64.776202      88.678228  96.450488  99.837287
#
#          avg_trans_fee_per_trans  block_reward  block_reward_tips  Bitcoin  \
# 1/2009                  0.000000         100.0           0.000000      0.0
# 2/2009                  0.000000         100.0           0.000000      0.0
# 3/2009                  0.000000         100.0           0.000000      0.0
# 4/2009                  0.000000         100.0           0.000000      0.0
# 5/2009                  0.000000         100.0           0.000000      0.0
# ...                          ...           ...                ...      ...
# 9/2020                  5.415811           0.0          11.192310     13.0
# 10/2020                 7.470022           0.0          15.438766     13.0
# 11/2020                 9.831252           0.0          20.288305     23.0
# 12/2020                 3.903002           0.0           8.056684     31.0
# 1/2021                  5.206379           0.0          10.746525     64.0
#
#            Ethereum  isPartial
# 1/2009     0.000000        0.0
# 2/2009     0.000000        0.0
# 3/2009     0.000000        0.0
# 4/2009     0.000000        0.0
# 5/2009     0.000000        0.0
# ...             ...        ...
# 9/2020    18.181818        0.0
# 10/2020    9.090909        0.0
# 11/2020   27.272727        0.0
# 12/2020   27.272727        0.0
# 1/2021   100.000000        0.0
#
# [145 rows x 11 columns]

# %%
# Create subplots
fig, ax = plt.subplots()
line1, = ax.plot(block_and_trends_scaled['Bitcoin'], label="Bitcoin Interest")
line2, = ax.plot(block_and_trends_scaled['size'], label="Size")

# Create a legend for the plot
first_legend = ax.legend(handles=[line1,line2,line3], loc='upper left')

# Add the legend manually to the Axes.
ax.add_artist(first_legend)

# Label the x and y axis
plt.xlabel("Time")
plt.ylabel("Price and Interest (Scaled from 1-100)")

# Add a title to the plot
plt.title("Crypto Search and Block Data")

# Save the plot to present directory
plt.rcParams["figure.figsize"] = (20,12)

# Show the plot
plt.show()

# %%
# Show Correlation
block_and_trends_corr = block_and_trends.corr(method='pearson')
block_and_trends_corr.to_csv("correlation\\block_and_trends_corr.csv")
block_and_trends_corr
# Out:
#                            height    volume  stripped_size      size  \
# height                   1.000000  0.788857       0.783032  0.824290
# volume                   0.788857  1.000000       0.907366  0.942120
# stripped_size            0.783032  0.907366       1.000000  0.974877
# size                     0.824290  0.942120       0.974877  1.000000
# weight                   0.799018  0.922117       0.997925  0.987194
# avg_trans_fee_per_trans -0.047837  0.017954       0.015273 -0.020864
# block_reward            -0.936178 -0.723766      -0.760779 -0.770656
# block_reward_tips        0.377206  0.544924       0.588991  0.520569
# Bitcoin                  0.571195  0.534204       0.547385  0.562493
# Ethereum                 0.499174  0.439904       0.520764  0.523131
# isPartial                     NaN       NaN            NaN       NaN
#
#                            weight  avg_trans_fee_per_trans  block_reward  \
# height                   0.799018                -0.047837     -0.936178
# volume                   0.922117                 0.017954     -0.723766
# stripped_size            0.997925                 0.015273     -0.760779
# size                     0.987194                -0.020864     -0.770656
# weight                   1.000000                 0.004908     -0.767580
# avg_trans_fee_per_trans  0.004908                 1.000000      0.022688
# block_reward            -0.767580                 0.022688      1.000000
# block_reward_tips        0.572270                 0.410056     -0.422997
# Bitcoin                  0.554591                 0.090907     -0.544755
# Ethereum                 0.524149                 0.092126     -0.470543
# isPartial                     NaN                      NaN           NaN
#
#                          block_reward_tips   Bitcoin  Ethereum  isPartial
# height                            0.377206  0.571195  0.499174        NaN
# volume                            0.544924  0.534204  0.439904        NaN
# stripped_size                     0.588991  0.547385  0.520764        NaN
# size                              0.520569  0.562493  0.523131        NaN
# weight                            0.572270  0.554591  0.524149        NaN
# avg_trans_fee_per_trans           0.410056  0.090907  0.092126        NaN
# block_reward                     -0.422997 -0.544755 -0.470543        NaN
# block_reward_tips                 1.000000  0.549051  0.513984        NaN
# Bitcoin                           0.549051  1.000000  0.893037        NaN
# Ethereum                          0.513984  0.893037  1.000000        NaN
# isPartial                              NaN       NaN       NaN        NaN

# %%
plt.subplots(figsize= (20,12))
sns.heatmap(block_and_trends_corr, annot= True, fmt= '.2%')
plt.title("Block and Trends Correlation")
plt.savefig("plots\\block_and_trends_corr.jpg", dpi = 300)

# %%
# Concatendate the two dataframes
block_data =  pd.read_csv("dataset.csv",low_memory=False)
# block_data = btc_df.set_index(btc_df['height'])
# block_data.drop(['host','block_reward','height'],inplace=True,axis=1)
# block_data
# df_concat = pd.concat([btc_df,btc_price],axis=1)

# %%
dic = {}
for i in list(block_data.index):
    lst = [ ]
    for k in [block_data[c][i] for c in block_data.columns]:
        if type(k) == str:
            key = k.split(" ")[0]
        else:
            lst.append(k)
            
    if key not in dic.keys():
        dic[key] = lst
# block_data_new = pd.DataFrame.from_dict(data=dic,orient='index',columns=list(block_data.columns)[:-1])
block_data_new = pd.DataFrame.from_dict(data=dic,orient='index')

# %%
block_data_new = block_data.set_index(btc_price.index)
price_and_data = pd.concat([test,btc_price],axis=1)
price_and_data
# Out:
#             volume  stripped_size     size   weight  avg_trans_fee_per_trans  \
# Date
# 2014-09-17    1092         603041   603041  2412164                 0.000068
# 2014-09-18     350         143076   143076   572304                 0.000087
# 2014-09-19     396         235727   235727   942908                 0.000066
# 2014-09-20     919         629794   629794  2519176                 0.000065
# 2014-09-21    1113         505590   505590  2022360                 0.000077
# ...            ...            ...      ...      ...                      ...
# 2021-01-14    1476         940052  1173270  3993426                 0.000351
# 2021-01-15    1752         886871  1332694  3993307                 0.000357
# 2021-01-16    2722         834008  1491318  3993342                 0.000354
# 2021-01-17    2359         914210  1250873  3993503                 0.000307
# 2021-01-18    1669         882134  1347200  3993602                 0.000122
#
#             block_reward_tips          Open          High           Low  \
# Date
# 2014-09-17           0.164946    465.864014    468.174011    452.421997
# 2014-09-18           0.049661    456.859985    456.859985    413.104004
# 2014-09-19           0.062611    424.102997    427.834991    384.532013
# 2014-09-20           0.162859    394.673004    423.295990    389.882996
# 2014-09-21           0.155930    408.084991    412.425995    393.181000
# ...                       ...           ...           ...           ...
# 2021-01-14           1.400926  37325.109375  39966.406250  36868.562500
# 2021-01-15           1.425750  39156.707031  39577.710938  34659.589844
# 2021-01-16           1.413416  36821.648438  37864.367188  35633.554688
# 2021-01-17           1.227162  36163.648438  36722.351562  34069.320312
# 2021-01-18           0.485747  35792.238281  37299.285156  34883.843750
#
#                    Close     Adj Close       Volume
# Date
# 2014-09-17    457.334015    457.334015     21056800
# 2014-09-18    424.440002    424.440002     34483200
# 2014-09-19    394.795990    394.795990     37919700
# 2014-09-20    408.903992    408.903992     36863600
# 2014-09-21    398.821014    398.821014     26580100
# ...                  ...           ...          ...
# 2021-01-14  39187.328125  39187.328125  63615990033
# 2021-01-15  36825.367188  36825.367188  67760757881
# 2021-01-16  36178.140625  36178.140625  57706187875
# 2021-01-17  35791.277344  35791.277344  52359854336
# 2021-01-18  36630.074219  36630.074219  49511702429
#
# [2316 rows x 12 columns]

# %%
#Scale the data
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0, 100))
scaled = min_max_scaler.fit_transform(price_and_data)
pad_scaled = pd.DataFrame(scaled, columns = price_and_data.columns)
pad_scaled = pad_scaled.set_index(price_and_dataata.index)
# pad_scaled.to_csv("data\\scale.csv")
pad_scaled
# Out:
#                volume  stripped_size       size     weight  \
# Date
# 2014-09-17  23.681354      60.296834  31.633502  60.296834
# 2014-09-18   7.575429      14.291915   7.497961  14.291915
# 2014-09-19   8.573909      23.558711  12.359597  23.558711
# 2014-09-20  19.926199      62.972624  33.037301  62.972624
# 2014-09-21  24.137183      50.549951  26.519999  50.549951
# ...               ...            ...        ...        ...
# 2021-01-14  32.016497      94.004103  61.554877  99.835620
# 2021-01-15  38.007380      88.685029  69.920263  99.832644
# 2021-01-16  59.062297      83.397762  78.243670  99.833520
# 2021-01-17  51.182982      91.419430  65.626905  99.837545
# 2021-01-18  36.205774      88.211243  70.681430  99.840021
#
#             avg_trans_fee_per_trans  block_reward_tips       Open       High  \
# Date
# 2014-09-17                 2.428940           1.467349   0.711536   0.614455
# 2014-09-18                 3.082175           0.441780   0.689365   0.587346
# 2014-09-19                 2.358608           0.556979   0.608706   0.517800
# 2014-09-20                 2.296446           1.448778   0.536239   0.506925
# 2014-09-21                 2.738685           1.387140   0.569264   0.480879
# ...                             ...                ...        ...        ...
# 2021-01-14                12.461193          12.462512  91.471602  95.254986
# 2021-01-15                12.682490          12.683351  95.981621  94.323645
# 2021-01-16                12.572374          12.573624  90.231909  90.218353
# 2021-01-17                10.915310          10.916724  88.611688  87.482004
# 2021-01-18                 4.320444           4.321167  87.697149  88.864377
#
#                   Low      Close  Adj Close     Volume
# Date
# 2014-09-17   0.723825   0.687431   0.687431   0.012279
# 2014-09-18   0.622515   0.606450   0.606450   0.023167
# 2014-09-19   0.548893   0.533470   0.533470   0.025954
# 2014-09-20   0.562681   0.568202   0.568202   0.025098
# 2014-09-21   0.571179   0.543379   0.543379   0.016758
# ...               ...        ...        ...        ...
# 2021-01-14  94.557209  96.035695  96.035695  51.583550
# 2021-01-15  88.865355  90.220851  90.220851  54.944682
# 2021-01-16  91.374968  88.627462  88.627462  46.791093
# 2021-01-17  87.344409  87.675054  87.675054  42.455571
# 2021-01-18  89.443189  89.740064  89.740064  40.145909
#
# [2316 rows x 12 columns]

# %%
# Create subplots
fig, ax = plt.subplots()
line1, = ax.plot(pad_scaled['avg_trans_fee_per_trans'], label="Bitcoin Transaction Fees")
line2, = ax.plot(pad_scaled['Volume'], label="Trading Volume")
line3, = ax.plot(pad_scaled['Open'], label="Trading Volume")
# line3, = ax.plot(df_scale['High'], label="Price")
# line4, = ax.plot(df_scale['High'], label="Price")
# line5, = ax.plot(df_scale['High'], label="Price")

# Create a legend for the plot
first_legend = ax.legend(handles=[line1,line2,line3], loc='upper left')

# Add the legend manually to the Axes.
ax.add_artist(first_legend)

# Label the x and y axis
plt.xlabel("Time")
plt.ylabel("Price and Interest (Scaled from 1-100)")

# Add a title to the plot
plt.title("Crypto Price and Block Data")

# Save the plot to present directory
plt.rcParams["figure.figsize"] = (20,12)

# Show the plot
plt.show()

# %%
# Show Correlation
pad_corr = pad_scaled.corr(method='pearson')
pad_corr.to_csv("correlation\\pad_corr.csv")
pad_corr
# Out:
#                            volume  stripped_size      size    weight  \
# volume                   1.000000       0.704247  0.755034  0.750000
# stripped_size            0.704247       1.000000  0.821301  0.982057
# size                     0.755034       0.821301  1.000000  0.914152
# weight                   0.750000       0.982057  0.914152  1.000000
# avg_trans_fee_per_trans  0.198227       0.283066  0.127659  0.243336
# block_reward_tips        0.263599       0.368705  0.210854  0.331689
# Open                     0.287412       0.191818  0.506429  0.303707
# High                     0.285065       0.192695  0.502717  0.303103
# Low                      0.290165       0.191671  0.512665  0.305664
# Close                    0.285647       0.191934  0.505699  0.303547
# Adj Close                0.285647       0.191934  0.505699  0.303547
# Volume                   0.282685       0.156299  0.520251  0.283037
#
#                          avg_trans_fee_per_trans  block_reward_tips      Open  \
# volume                                  0.198227           0.263599  0.287412
# stripped_size                           0.283066           0.368705  0.191818
# size                                    0.127659           0.210854  0.506429
# weight                                  0.243336           0.331689  0.303707
# avg_trans_fee_per_trans                 1.000000           0.985399  0.191395
# block_reward_tips                       0.985399           1.000000  0.217569
# Open                                    0.191395           0.217569  1.000000
# High                                    0.197792           0.223786  0.999029
# Low                                     0.179066           0.205527  0.998276
# Close                                   0.189208           0.215310  0.998064
# Adj Close                               0.189208           0.215310  0.998064
# Volume                                  0.009561           0.037992  0.786681
#
#                              High       Low     Close  Adj Close    Volume
# volume                   0.285065  0.290165  0.285647   0.285647  0.282685
# stripped_size            0.192695  0.191671  0.191934   0.191934  0.156299
# size                     0.502717  0.512665  0.505699   0.505699  0.520251
# weight                   0.303103  0.305664  0.303547   0.303547  0.283037
# avg_trans_fee_per_trans  0.197792  0.179066  0.189208   0.189208  0.009561
# block_reward_tips        0.223786  0.205527  0.215310   0.215310  0.037992
# Open                     0.999029  0.998276  0.998064   0.998064  0.786681
# High                     1.000000  0.997988  0.999236   0.999236  0.787103
# Low                      0.997988  1.000000  0.998822   0.998822  0.785990
# Close                    0.999236  0.998822  1.000000   1.000000  0.786690
# Adj Close                0.999236  0.998822  1.000000   1.000000  0.786690
# Volume                   0.787103  0.785990  0.786690   0.786690  1.000000

# %%
plt.subplots(figsize= (20,12))
sns.heatmap(pad_corr, annot= True, fmt= '.2%')
plt.title("Bitcoin Block & Price Data")
plt.savefig("plots\\pad_corr.jpg", dpi = 300)

# %%
for i in iot.index:
    # print(str(i)[8:10])
    if int(str(i)[2:4]) < 14:
        iot.drop(i, inplace=True)
    if str(i)[2:4] == '14' and int(str(i)[5:7]) < 10:
        iot.drop(i, inplace=True)
iot.drop('isPartial',inplace=True,axis=1)

# %%
# Concatendate the two dataframes
btc_df =  pd.read_csv("dataset.csv")
btc_df.drop('host',inplace=True,axis=1)
df_concat = pd.concat([iot,btc],axis=1)
btc_df = btc_df.truncate(before=323278)
btc_df
# Out:
#         height  volume  stripped_size     size   weight  \
# 323278  323270      96          63007    63007   252028
# 323279  323271    1173         607835   607835  2431340
# 323280  323272     419         232124   232124   928496
# 323281  323273     274         154179   154179   616716
# 323282  323274     377         189472   189472   757888
# ...        ...     ...            ...      ...      ...
# 666611  666594    1968         881571  1348518  3993231
# 666612  666595    2474         893448  1312647  3992991
# 666613  666596    1896         819022  1541514  3998580
# 666614  666597    2192         912273  1256245  3993064
# 666615  666598    2331         886781  1333038  3993381
#
#         avg_trans_fee_per_trans  block_reward  block_reward_tips  \
# 323278                 0.000017         25.00           0.004300
# 323279                 0.000071         25.00           0.173676
# 323280                 0.000067         25.00           0.062366
# 323281                 0.000055         25.00           0.034045
# 323282                 0.000081         25.00           0.061242
# ...                         ...           ...                ...
# 666611                 0.000239          6.25           0.953732
# 666612                 0.000160          6.25           0.637013
# 666613                 0.000123          6.25           0.493446
# 666614                 0.000040          6.25           0.158978
# 666615                 0.000117          6.25           0.466599
#
#                    time
# 323278   1/10/2014 0:02
# 323279   1/10/2014 0:25
# 323280   1/10/2014 0:33
# 323281   1/10/2014 0:37
# 323282   1/10/2014 0:43
# ...                 ...
# 666611  18/1/2021 10:29
# 666612  18/1/2021 10:33
# 666613  18/1/2021 10:41
# 666614  18/1/2021 10:40
# 666615  18/1/2021 10:48
#
# [343338 rows x 9 columns]

# %%
#Scale the data
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0, 100))
scaled = min_max_scaler.fit_transform(df_concat)
df_scale = pd.DataFrame(scaled, columns = df_concat.columns)
df_scale = df_scale.set_index(df_concat.index)
df_scale.to_csv("data\\btc_eth_price_to_trends.csv")
df_scale
# Out:
#               Bitcoin   Ethereum       High        Low       Open      Close  \
# 2014-10-01   1.020408   0.000000   0.257547   0.283719   0.279133   0.264372
# 2014-11-01   1.020408   0.000000   0.175779   0.183312   0.199306   0.169168
# 2014-12-01   1.020408   0.000000   0.245138   0.276808   0.264112   0.257182
# 2015-01-01   1.020408   0.000000   0.143467   0.171457   0.169496   0.150248
# 2015-02-01   1.020408   0.000000   0.000576   0.000000   0.000000   0.006657
# ...               ...        ...        ...        ...        ...        ...
# 2022-01-01  36.734694  40.909091  76.536082  77.461357  75.437278  78.089389
# 2022-02-01  32.653061  31.818182  62.526612  63.718275  62.623004  63.375139
# 2022-03-01  27.551020  27.272727  71.657776  71.853218  70.335708  72.607167
# 2022-04-01  21.428571  22.727273  74.588642  74.291815  74.197445  75.777553
# 2022-05-01  22.448980  22.727273  61.743060  62.830839  61.365303  62.924048
#
#                Volume  Adj Close
# 2014-10-01   0.029505   0.264372
# 2014-11-01   0.014013   0.169168
# 2014-12-01   0.006043   0.257182
# 2015-01-01   0.000000   0.150248
# 2015-02-01   0.034206   0.006657
# ...               ...        ...
# 2022-01-01  39.854332  78.089389
# 2022-02-01  32.890193  63.375139
# 2022-03-01  52.660424  72.607167
# 2022-04-01  61.877895  75.777553
# 2022-05-01  43.779160  62.924048
#
# [92 rows x 8 columns]

# %%
bpi_corr = df_scale.corr(method='pearson')
bpi_corr.to_csv("correlation\\bpi_corr.csv")
bpi_corr
# Out:
#             Bitcoin  Ethereum      High       Low      Open     Close  \
# Bitcoin    1.000000  0.850388  0.667348  0.663064  0.666334  0.666257
# Ethereum   0.850388  1.000000  0.843409  0.843146  0.845239  0.841750
# High       0.667348  0.843409  1.000000  0.999463  0.999460  0.999804
# Low        0.663064  0.843146  0.999463  1.000000  0.999758  0.999423
# Open       0.666334  0.845239  0.999460  0.999758  1.000000  0.999083
# Close      0.666257  0.841750  0.999804  0.999423  0.999083  1.000000
# Volume     0.608616  0.650091  0.786105  0.783231  0.784336  0.785568
# Adj Close  0.666257  0.841750  0.999804  0.999423  0.999083  1.000000
#
#              Volume  Adj Close
# Bitcoin    0.608616   0.666257
# Ethereum   0.650091   0.841750
# High       0.786105   0.999804
# Low        0.783231   0.999423
# Open       0.784336   0.999083
# Close      0.785568   1.000000
# Volume     1.000000   0.785568
# Adj Close  0.785568   1.000000

# %%
# Create subplots
fig, ax = plt.subplots()
line1, = ax.plot(df_scale['Bitcoin'], label="Searches")
line2, = ax.plot(df_scale['Volume'], label="Trading Volume")
line3, = ax.plot(df_scale['High'], label="Price")

# Create a legend for the plot
first_legend = ax.legend(handles=[line1,line2,line3], loc='upper left')

# Add the legend manually to the Axes.
ax.add_artist(first_legend)

# Label the x and y axis
plt.xlabel("Time")
plt.ylabel("Price and Interest (Scaled from 1-100)")

# Add a title to the plot
plt.title("Bitcoin Price & Search Graph")

# Save the plot to present directory
plt.rcParams["figure.figsize"] = (20,12)
plt.savefig("plots\\btc_price_and_interest.jpg", dpi = 300)

# Show the plot
plt.show()

# %%
plt.subplots(figsize= (20,12))
sns.heatmap(bpi_corr, annot= True, fmt= '.2%')
plt.title("Bitcoin Price & Search Data")
plt.savefig("plots\\bpi_corr.jpg", dpi = 300)

# %% [markdown]
# # OTHER

# %%
# Plot BTC Volume
btc['Volume'].plot(figsize=(10, 6))
# Label the x and y axis
plt.xlabel("Date")
plt.ylabel("Price")
# Save the plot to present directory
plt.savefig("plots\\btc_volume.png")

# %%
# initialize a new Google Trends Request Object
pt = TrendReq(hl="en-US", tz=360)
# set the keyword & timeframe
keywords = ["Coinbase", "Binance"]
pt.build_payload(keywords, timeframe="all")
# get the interest over time
exch_iot = pt.interest_over_time()
# Save iot as a .csv file in the current directory
exch_iot.to_csv("data\\exch_iot.csv")
exch_iot
# Out:
#             Coinbase  Binance  isPartial
# date
# 2004-01-01         0        0      False
# 2004-02-01         0        0      False
# 2004-03-01         0        0      False
# 2004-04-01         0        0      False
# 2004-05-01         0        0      False
# ...              ...      ...        ...
# 2022-01-01         5       10      False
# 2022-02-01         4        7      False
# 2022-03-01         3        7      False
# 2022-04-01         3        7      False
# 2022-05-01         3        6       True
#
# [221 rows x 3 columns]

# %%
# Create subplots
fig, ax = plt.subplots()
line1, = ax.plot(exch_iot['Coinbase'].truncate(before=list(exch_iot.index)[145]), label="Coinbase")
line2, = ax.plot(exch_iot['Binance'].truncate(before=list(exch_iot.index)[145]), label="Binance")

# Create a legend for the plot
first_legend = ax.legend(handles=[line1,line2], loc='upper left')

# Add the legend manually to the Axes.
ax.add_artist(first_legend)

# Label the x and y axis
plt.xlabel("Date")
plt.ylabel("Relative Interest")

# Add a title to the plot
plt.title("Crypto Exchange Interest Over Time")

# Save the plot to present directory
plt.rcParams["figure.figsize"] = (20,12)
plt.savefig("plots\\exch_iot.jpg", dpi = 300)

# Show the plot
plt.show()

# %%
# Plot BTC Volume
btc['High'].plot(figsize=(10, 6))
# Label the x and y axis
plt.xlabel("Date")
plt.ylabel("Price")
# Save the plot to present directory
plt.savefig("plots\\btc_volume.png")
